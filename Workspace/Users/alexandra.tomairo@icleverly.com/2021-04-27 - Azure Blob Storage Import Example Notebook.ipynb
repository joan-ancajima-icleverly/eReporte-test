# %% [markdown]
# This notebook shows you how to create and query a table or DataFrame loaded from data stored in Azure Blob storage.

# %% [markdown]
# ### Step 1: Set the data location and type
#
# There are two ways to access Azure Blob storage: account keys and shared access signatures (SAS).
#
# To get started, we need to set the location and type of the file.

# %%
from pyspark.sql import SQLContext
sqlContext = SQLContext(sc)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
storage_account_name = "interfacesseir"
storage_account_access_key = "NRTuXaUT9TyHDDAKRhvdBESuKbSUAMbGnfvPu+/tfSECDc+C2qa82Lo3Nbtod/vB3NqcjN9rGBKAqJwZ5vs5sw=="
container = "inseir"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.conf.set(
  "fs.azure.account.key."+storage_account_name+".blob.core.windows.net",
  storage_account_access_key)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.ls(f"wasbs://{container}@{storage_account_name}.blob.core.windows.net")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: [FileInfo(path=&#39;wasbs://inseir@interfacesseir.blob.core.windows.net/FORMATORCD202101.DAT&#39;, name=&#39;FORMATORCD202101.DAT&#39;, size=273),
#  FileInfo(path=&#39;wasbs://inseir@interfacesseir.blob.core.windows.net/FORMATORCD202101.csv&#39;, name=&#39;FORMATORCD202101.csv&#39;, size=273),
#  FileInfo(path=&#39;wasbs://inseir@interfacesseir.blob.core.windows.net/FORMATORCD202101.txt&#39;, name=&#39;FORMATORCD202101.txt&#39;, size=273),
#  FileInfo(path=&#39;wasbs://inseir@interfacesseir.blob.core.windows.net/SBSCAMDIA22420210331.txt&#39;, name=&#39;SBSCAMDIA22420210331.txt&#39;, size=542),
#  FileInfo(path=&#39;wasbs://inseir@interfacesseir.blob.core.windows.net/SBSCUC20210331.txt&#39;, name=&#39;SBSCUC20210331.txt&#39;, size=4706),
#  FileInfo(path=&#39;wasbs://inseir@interfacesseir.blob.core.windows.net/SBSCUC20210331_DET.txt&#39;, name=&#39;SBSCUC20210331_DET.txt&#39;, size=409),
#  FileInfo(path=&#39;wasbs://inseir@interfacesseir.blob.core.windows.net/SBSREF22400120210331.txt&#39;, name=&#39;SBSREF22400120210331.txt&#39;, size=3248),
#  FileInfo(path=&#39;wasbs://inseir@interfacesseir.blob.core.windows.net/SBSRNC00020170331.txt&#39;, name=&#39;SBSRNC00020170331.txt&#39;, size=69),
#  FileInfo(path=&#39;wasbs://inseir@interfacesseir.blob.core.windows.net/rcc202001.ope&#39;, name=&#39;rcc202001.ope&#39;, size=664),
#  FileInfo(path=&#39;wasbs://inseir@interfacesseir.blob.core.windows.net/rcd202102.224.ok&#39;, name=&#39;rcd202102.224.ok&#39;, size=724)]</div>

# %%
# %fs ls wasbs://inseir@interfacesseir.blob.core.windows.net/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>wasbs://inseir@interfacesseir.blob.core.windows.net/FORMATORCD202101.DAT</td><td>FORMATORCD202101.DAT</td><td>273</td></tr><tr><td>wasbs://inseir@interfacesseir.blob.core.windows.net/FORMATORCD202101.csv</td><td>FORMATORCD202101.csv</td><td>273</td></tr><tr><td>wasbs://inseir@interfacesseir.blob.core.windows.net/FORMATORCD202101.txt</td><td>FORMATORCD202101.txt</td><td>273</td></tr><tr><td>wasbs://inseir@interfacesseir.blob.core.windows.net/SBSCAMDIA22420210331.txt</td><td>SBSCAMDIA22420210331.txt</td><td>542</td></tr><tr><td>wasbs://inseir@interfacesseir.blob.core.windows.net/SBSCUC20210331.txt</td><td>SBSCUC20210331.txt</td><td>4706</td></tr><tr><td>wasbs://inseir@interfacesseir.blob.core.windows.net/SBSCUC20210331_DET.txt</td><td>SBSCUC20210331_DET.txt</td><td>409</td></tr><tr><td>wasbs://inseir@interfacesseir.blob.core.windows.net/SBSREF22400120210331.txt</td><td>SBSREF22400120210331.txt</td><td>3248</td></tr><tr><td>wasbs://inseir@interfacesseir.blob.core.windows.net/SBSRNC00020170331.txt</td><td>SBSRNC00020170331.txt</td><td>69</td></tr><tr><td>wasbs://inseir@interfacesseir.blob.core.windows.net/rcc202001.ope</td><td>rcc202001.ope</td><td>664</td></tr><tr><td>wasbs://inseir@interfacesseir.blob.core.windows.net/rcd202102.224.ok</td><td>rcd202102.224.ok</td><td>724</td></tr></tbody></table></div>

# %% [markdown]
# ### Step 2: Read the data
#
# Now that we have specified our file metadata, we can create a DataFrame. Notice that we use an *option* to specify that we want to infer the schema from the file. We can also explicitly set this to a particular schema if we have one already.
#
# First, let's create a DataFrame in Python.

# %%
df = sqlContext.read.text("wasbs://inseir@interfacesseir.blob.core.windows.net/FORMATORCD202101.DAT")
df.select(
    df.value.substr(1,12).alias('numCuenta'),
    df.value.substr(13,9).alias('codigoSbs'),
    df.value.substr(22,12).alias('numTarjeta'),
    df.value.substr(34,80).alias('nombre'),
    df.value.substr(114,15).alias('siglas'),
    df.value.substr(129,4).alias('ciiu'),
    df.value.substr(133,15).alias('regPublico'),
    df.value.substr(148,11).cast('integer').alias('ruc'),
    df.value.substr(159,1).alias('pft'),
    df.value.substr(160,1).alias('tipoDocumento'),
    df.value.substr(161,12).alias('NumDocumento'),
    df.value.substr(173,2).alias('residencia'),
    df.value.substr(175,1).alias('califCrediticia'),
    df.value.substr(176,2).alias('dft'),
    df.value.substr(178,2).alias('moneda'),
    df.value.substr(180,18).alias('saldo'),
    df.value.substr(198,14).alias('montoCredito'),
    df.value.substr(212,1).alias('tipoDocTributario'),
    df.value.substr(213,11).alias('numDocTributario'),
    df.value.substr(224,2).alias('filler'),
    df.value.substr(226,2).alias('tipoOperacion'),
    df.value.substr(228,2).alias('magnitudEmp'),
    df.value.substr(230,2).alias('accionista'),
    df.value.substr(232,2).alias('tipoTrib'),
    df.value.substr(234,8).alias('numTrib'),
    df.value.substr(242,1).alias('sexo'),
    df.value.substr(243,1).alias('estadoCivil'),
    df.value.substr(244,1).alias('tipoCliente'),
    df.value.substr(245,2).alias('paisResidencia'),
    df.value.substr(247,10).alias('fechaNac'),
    df.value.substr(257,2).alias('tipoDocIdeComplementario'),
    df.value.substr(259,12).alias('NumDocIdeComplementario')
).show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+---------+------------+--------------------+---------------+----+---------------+----+---+-------------+------------+----------+---------------+---+------+------------------+--------------+-----------------+----------------+------+-------------+-----------+----------+--------+--------+----+-----------+-----------+--------------+----------+------------------------+-----------------------+
#    numCuenta|codigoSbs|  numTarjeta|              nombre|         siglas|ciiu|     regPublico| ruc|pft|tipoDocumento|NumDocumento|residencia|califCrediticia|dft|moneda|             saldo|  montoCredito|tipoDocTributario|numDocTributario|filler|tipoOperacion|magnitudEmp|accionista|tipoTrib| numTrib|sexo|estadoCivil|tipoCliente|paisResidencia|  fechaNac|tipoDocIdeComplementario|NumDocIdeComplementario|
# +------------+---------+------------+--------------------+---------------+----+---------------+----+---+-------------+------------+----------+---------------+---+------+------------------+--------------+-----------------+----------------+------+-------------+-----------+----------+--------+--------+----+-----------+-----------+--------------+----------+------------------------+-----------------------+
# 007575037708|000000000|007575037708|XXXXXXXXXX XXXXXX...|               |    |               |null|   |            1|#####532    |          |              0| 20|    00|100000000000006899|B0000000326800|                {|                |      |             |          0|        00|      0 |        |    |          F|          C|            BN| 1964/02/0|                      4 |                       |
# +------------+---------+------------+--------------------+---------------+----+---------------+----+---+-------------+------------+----------+---------------+---+------+------------------+--------------+-----------------+----------------+------+-------------+-----------+----------+--------+--------+----+-----------+-----------+--------------+----------+------------------------+-----------------------+
#
# </div>

# %%
from pyspark.sql import *
import pandas as pd
from pyspark.sql.types import *

jdbchostname = "auqui.database.windows.net"
jdbcport = "1433"
jdbcDatabase = "dbnormativo"
properties = {
  "user":"administrador",
  "password": "Auqui$2020"
  }
url = "jdbc:sqlserver://{0}:{1};database={2}".format(jdbchostname,jdbcport,jdbcDatabase)

dbutils.widgets.text ('id_solicitud', '0', 'id_solicitud')
id_solicitud = dbutils.widgets.get("id_solicitud")

sql = "(select * from Solicitud where id = " + id_solicitud + ") as Solicitud"
df = spark.read.jdbc(url=url, table=sql, properties = properties)

fecha_proceso = df.where(df.id == id_solicitud).select('fechaProceso').collect()[0][0]
fechaProceso_str = fecha_proceso.strftime('%Y%m')

df = sqlContext.read.text("wasbs://inseir@interfacesseir.blob.core.windows.net/FORMATORCD"+fechaProceso_str+".DAT")
df0 = df.select(
    df.value.substr(1,12).alias('valor0'), 
    df.value.substr(13,9).alias('valor1'),
    df.value.substr(22,12).alias('valor2'),
    df.value.substr(34,80).alias('nombre')
)
df1 = DataFrameWriter(df0)
df1.jdbc(url=url, table="bf_FormatoRcd", mode="overwrite", properties=properties)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">StructType(List(StructField(numCuenta,StringType,false),StructField(codigoSbs,StringType,false),StructField(numTarjeta,StringType,false),StructField(nombre,StringType,true)))
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# 007575037708000000000007575037708XXXXXXXXXX XXXXXXXXXX                                                                                                         1#####532      02000100000000000006899B0000000326800{                0000          FCBN 1964/02/04              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# </div>

# %% [markdown]
# ### Step 3: Query the data
#
# Now that we have created our DataFrame, we can query it. For instance, you can identify particular columns to select and display.

# %%
display(df.select("EXAMPLE_COLUMN"))

# %% [markdown]
# ### Step 4: (Optional) Create a view or table
#
# If you want to query this data as a table, you can simply register it as a *view* or a table.

# %%
df.createOrReplaceTempView("YOUR_TEMP_VIEW_NAME")

# %% [markdown]
# We can query this view using Spark SQL. For instance, we can perform a simple aggregation. Notice how we can use `%sql` to query the view from SQL.

# %%
# %sql

SELECT EXAMPLE_GROUP, SUM(EXAMPLE_AGG) FROM YOUR_TEMP_VIEW_NAME GROUP BY EXAMPLE_GROUP

# %% [markdown]
# Since this table is registered as a temp view, it will be available only to this notebook. If you'd like other users to be able to query this table, you can also create a table from the DataFrame.

# %%
df.write.format("parquet").saveAsTable("MY_PERMANENT_TABLE_NAME")

# %%
val rowsRdd: RDD[Row] = sc.parallelize(
  Seq(
    Row("first", 2.0, 7.0),
    Row("second", 3.5, 2.5),
    Row("third", 7.0, 5.9)
  )
)

val df = spark.createDataFrame(rowsRdd).toDF("id", "val1", "val2")

df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-cyan-fg">  File </span><span class="ansi-green-fg">&#34;&lt;command-1147963942900019&gt;&#34;</span><span class="ansi-cyan-fg">, line </span><span class="ansi-green-fg">1</span>
# <span class="ansi-red-fg">    val rowsRdd: RDD[Row] = sc.parallelize(</span>
#         ^
# <span class="ansi-red-fg">SyntaxError</span><span class="ansi-red-fg">:</span> invalid syntax
# </div>

# %% [markdown]
# This table will persist across cluster restarts and allow various users across different notebooks to query this data.
